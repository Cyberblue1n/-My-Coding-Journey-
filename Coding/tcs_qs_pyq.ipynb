# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ayush is working on a strange algorithm where he wants to convert a string from A to B, both the strings of equal length N
#
# Below are the rules which can be performed to convert a string
# • String A and B are of equal length
# • Both of them are in lower case
# • Choose a subset X from the string A, between the index 1 and N.
# • Let ‘s’ be the letter which alphabetically comes before all other letters in the subset. Let ‘s’ be called the ‘smallest element’ in the subset.
# • Replace all the elements of subset with the letter ‘s’
#
# Find the minimum number of moves which is required to perform the conversion. If it is not possible to convert the string from A to b then return -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def palindrome(num):
    return str(num)==str(num)[::-1]

def check_repeating(num):
    num = str(num)
    return len(num)==(len(set(num)))

def cryptic_number(num1, num2):
    res = []
    for i in range(num1, num2+1):
        if i%7==0 and i%5!=0 and palindrome(i) is False and check_repeating(i):
            res.append(i)

    if res:
        print(*res)
    else:
        print(-1)

if __name__ == "__main__":
    num1 = 100
    num2 = 150
    cryptic_number(num1, num2)
# Out:
# 126 147

# %% [markdown]
# A teacher wants to teach kids about cube numbers. She gives them two integers and asks them to find the sum of cubes of all the numbers between those two values, inclusive. Help the kids solve this task!
#
# Sample Input: 1 3
#
# Sample Output: 36

# %%
def cube_sum(num1, num2):
    output = 0
    for i in range(num1, num2+1):
        output += i**3
    
    return output

if __name__ == "__main__":
    num1, num2 = 1, 3
    print(cube_sum(num1, num2))
# Out:
# 36

# %% [markdown]
# Time is integral part of our life. Soci horology which is the discipline of studying time and clock making. A watchmaker is passionate about delivering the best watches 7 with accurate time all over the world. Each watch he makes, he tests the time in it with a standard watch showing GMT of his place.
# The task here is to find if the new watch he made is working correctly and find the number of minutes (delay or early) such that: Compare the initial time (h, m) and the current time (h1, m1) in the new watch.
#
# The time after X hours in the new watch may be correct or incorrect.. Display the number of minutes by which new watch is lagging or early from the actual time. If the time is lagging display positive integer an if the time is early display the negative integer.
#
# Given a initial time in h:m and current time h1:m2 and x display the delays in minutes in from the initial time after x hours (TCS off campus NQT 2023)

# %% [markdown]
# Problem Name: Prime Index Sum CalculationProblem
#
# Description: You are given two integers X and Y.
# Your task is to: Find the Xth prime number → call it AFind the Yth prime number → call it B
#
# Calculate and print the value of C = (A + B) - 1
#
# Input Format:
# A single line with two space-separated integers X and Y
#
# Output Format: A single integer C which is calculated as (A + B) - 1
#
# Constraints:$1 \le X, Y \le 10^4
#
# Examples:
#
# Input: 2 3
#
# Output: 7

# %%
def prime_index_sum(n1):
    count = 0
    for i in range(1, n1+1):
        
    return 
if __name__ == "__main__":

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. A chocolate factory is packing chocolates into the packets. The chocolate packets here represent an array of N number of integer values. The task is to find the empty packets(0) of chocolate and push it to the end of the conveyor belt(array). Click here to see solution
# Example 1 : N=8 and arr = [4,5,0,1,9,0,5,0].
#
# There are 3 empty packets in the given set. These 3 empty packets represented as O should be pushed towards the end of the array
#
# Input :
#
# 8 – Value of N
#
# [4,5,0,1,9,0,5,0] – Element of arr[O] to arr[N-1],While input each element is separated by newline
#
# Output:
#
# 4 5 1 9 5 0 0 0
#
# Example 2:
#
# Input:
#
# 6 — Value of N.
#
# [6,0,1,8,0,2] – Element of arr[0] to arr[N-1], While input each element is separated by newline
#
# Output:
#
# 6 1 8 2 0 0

# %%
# !lscpu
# Out:
# 'lscpu' is not recognized as an internal or external command,
# operable program or batch file.

# %%
'''
Explanation

Each String is left-justified with trailing whitespace through the first 15 characters. The leading digit of the integer is the 16th character, and each integer that was less than 3 digits now has leading zeroes.


input given:

java 100
cpp 65
python 50

==============================  (30 len)
'''

def string_problem(str1, str2):
    return ("%-15s%03d" % (str1, int(str2)))


if __name__ == "__main__":
    print("="*30)

    for _ in range(3):
        str1, str2 = input().split()
        print(string_problem(str1, str2))

    print("="*30)
# Out:
# ...
# java           100
# cpp            065
# python         050
# ...
